# %%
# -*- coding: utf-8 -*-
import os
import mwclient
import json
import time
import re
import requests
from bs4 import BeautifulSoup
import lxml
from lxml.html import fromstring

import xlwt
import xlrd
import warnings
warnings.filterwarnings('ignore')

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import pandas as pd

# %%
url_nbh = "https://en.wikipedia.org/wiki/Category:Neighbourhoods_of_Jerusalem"
webdata_nbh = requests.get(url_nbh)
soup_nbh = BeautifulSoup(webdata_nbh.text, "html.parser")
# neighborhoods chose from 'Pages in category "Neighbourhoods of Jerusalem"'
list_nbh = soup_nbh.find_all('div', attrs={'class':'mw-category-group'})

# %%
url_lop = "https://en.wikipedia.org/wiki/List_of_places_in_Jerusalem"
webdata_lop = requests.get(url_lop)
root = fromstring(webdata_lop.content)
table = root.xpath(".//h2[span = 'Neighborhoods']/following-sibling::table")[0]
row = table.xpath(".//tr")[0]
list_lop = [cell.xpath(".//li") for cell in row.xpath(".//td")]

# %%
links, titles = [], []
for i in range(12, 34):
    temp_list = list_nbh[i].find_all('li')
    for item in temp_list:
        link = item.find('a')['href']
        link = 'https://en.wikipedia.org/'+str(link)
        title = item.find('a')['title']
        links.append(link)
        titles.append(title)

# %%
links2, titles2 = [], []
for sub_list in list_lop:
    for item in sub_list:
        link = item[0].get('href')
        link = 'https://en.wikipedia.org/'+str(link)
        title = item[0].get('title')
        links2.append(link)
        titles2.append(title)

# %%
workbook = xlwt.Workbook(r'wiki_nbh_info.xls')
sheet = workbook.add_sheet('wiki_nbh', cell_overwrite_ok=True)
sheet2 = workbook.add_sheet('wiki_lop', cell_overwrite_ok=True)
for i in range(len(links)):
    sheet.write(i, 0, titles[i])
    sheet.write(i, 1, links[i])
    sheet.write(i, 2, 'Category:Neighbourhoods_of_Jerusalem')
for i in range(len(links2)):
    sheet2.write(i, 0, titles2[i])
    sheet2.write(i, 1, links2[i])
    sheet2.write(i, 2, 'List_of_places_in_Jerusalem: Neighborhoods')
workbook.save(r"wiki_nbh_info.xls")

# %%
def get_coord(links):
    coord_urls, latitudes, longitudes = [], [], []
    for url in links:   
        webdata = requests.get(url)
        soup = BeautifulSoup(webdata.text, "html.parser")
        try:
            coord = soup.find(id = 'coordinates').findChild('span').findChild('a')
        except:
            coord_url = None
            latitude = None
            longitude = None
        else:
            coord_url = coord['href']
            latitude = coord.findChild('span').findChild('span').findChildren('span')[0].get_text()
            longitude = coord.findChild('span').findChild('span').findChildren('span')[1].get_text()
        coord_urls.append(coord_url)
        latitudes.append(latitude)
        longitudes.append(longitude)
    return coord_urls, latitudes, longitudes

# %%
# xls format
# wb_rd = xlrd.open_workbook(r'jerusalem_data.xls')
# sheet_rd = wb_rd.sheet_by_index(0)
# titles3 = sheet_rd.col_values(0, start_rowx=1)

# csv format
book_df = pd.read_csv('jerusalem_data_1.0.csv', header=1)
book_df['source_book'] = 1
book_df
headerlist = book_df.columns.values.tolist()
headerlist
# Out:
# ['Neighborhood',
#  'Year founded',
#  'Inhabitants',
#  'Initiative',
#  'Remarks',
#  'Notes',
#  'source_book']

# %%
# csv format
book_df = pd.read_csv('jerusalem_data.csv')
book_df['source_book'] = 1
book_df = book_df.rename(columns={'Year founded':'Original_year_info','Year founded int':'Year_founded'})
book_df
# Out:
#                         Neighborhood Original_year_info  Year_founded  \
# 0               Mishkenot Sha'ananim          1855-1860          1855
# 1                   Mahaneh Yisra’el               1866          1866
# 2                     Nanalat Shiv’a               1869          1869
# 3    Georgian Houses (Eshel Avraham)          1872-1876          1872
# 4         Bet David (Yanover Houses)               1873          1873
# ..                               ...                ...           ...
# 160                           Romema               1922          1922
# 161                         Dajania*      Early Mandate          1947
# 162                     al-Musallaba      Early Mandate          1947
# 163                  St. Louis Road*      Early Mandate          1947
# 164                    Macrae Estate             1930s?          1930
#
#                               Inhabitants                    Initiative  \
# 0                     Ashkenazi, Sephardi                 Philanthropic
# 1                              Maghrebian                       Private
# 2                     Ashkenazi, Sephardi                       Private
# 3                                Georgian  Building society and private
# 4                               Ashkenazi                 Philanthropic
# ..                                    ...                           ...
# 160  Ashkenazi and Oriental Jews, Muslims                       Private
# 161                   Muslims, Christians                       Private
# 162                   Mixed (mainly Jews)                           NaN
# 163             Jews, Muslims, Christians                           NaN
# 164                         Jews, Muslims                       Private
#
#                        Remarks            Type of neighborhood  source_book
# 0                          NaN  Jewish and mixed neighborhoods            1
# 1                          NaN  Jewish and mixed neighborhoods            1
# 2                          NaN  Jewish and mixed neighborhoods            1
# 3                          NaN  Jewish and mixed neighborhoods            1
# 4                          NaN  Jewish and mixed neighborhoods            1
# ..                         ...                             ...          ...
# 160  Named after Psalms 118:16             Mixed neighborhoods            1
# 161                        NaN             Mixed neighborhoods            1
# 162           Part of Rehavia?             Mixed neighborhoods            1
# 163                        NaN             Mixed neighborhoods            1
# 164               Near Rehavia             Mixed neighborhoods            1
#
# [165 rows x 8 columns]

# %%
# create wiki df source_NoJ
nbh_df = pd.DataFrame(data=[titles, links]).T
nbh_df.columns = ['titles','links']
nbh_df['source_NoJ'] = 1
nbh_df
# Out:
#                          titles  \
# 0                       Abu Tor
# 1    American Colony, Jerusalem
# 2              Armenian Quarter
# 3                        Arnona
# 4                  Arzei HaBira
# ..                          ...
# 146                 Yemin Moshe
# 147               Zikhron Moshe
# 148               Zikhron Tuvya
# 149               Zikhron Yosef
# 150                  Mount Zion
#
#                                                  links  source_NoJ
# 0               https://en.wikipedia.org//wiki/Abu_Tor           1
# 1    https://en.wikipedia.org//wiki/American_Colony...           1
# 2      https://en.wikipedia.org//wiki/Armenian_Quarter           1
# 3                https://en.wikipedia.org//wiki/Arnona           1
# 4          https://en.wikipedia.org//wiki/Arzei_HaBira           1
# ..                                                 ...         ...
# 146         https://en.wikipedia.org//wiki/Yemin_Moshe           1
# 147       https://en.wikipedia.org//wiki/Zikhron_Moshe           1
# 148       https://en.wikipedia.org//wiki/Zikhron_Tuvya           1
# 149       https://en.wikipedia.org//wiki/Zikhron_Yosef           1
# 150          https://en.wikipedia.org//wiki/Mount_Zion           1
#
# [151 rows x 3 columns]

# %%
# create wiki df source_LoP
lop_df = pd.DataFrame(data=[titles2, links2]).T
lop_df.columns=['titles','links']
lop_df['source_LoP'] = 1
lop_df = lop_df.drop_duplicates()
lop_df
# Out:
#                        titles  \
# 0                     Abu Tor
# 1    At-Tur (Mount of Olives)
# 2                      Arnona
# 3                      Ar-Ram
# 4                      Atarot
# ..                        ...
# 104               Wadi al-Joz
# 105                 Yefeh Nof
# 106               Yemin Moshe
# 107             Zichron Moshe
# 108             Zichron Yosef
#
#                                                  links  source_LoP
# 0               https://en.wikipedia.org//wiki/Abu_Tor           1
# 1    https://en.wikipedia.org//wiki/At-Tur_(Mount_o...           1
# 2                https://en.wikipedia.org//wiki/Arnona           1
# 3                https://en.wikipedia.org//wiki/Ar-Ram           1
# 4                https://en.wikipedia.org//wiki/Atarot           1
# ..                                                 ...         ...
# 104         https://en.wikipedia.org//wiki/Wadi_al-Joz           1
# 105           https://en.wikipedia.org//wiki/Yefeh_Nof           1
# 106         https://en.wikipedia.org//wiki/Yemin_Moshe           1
# 107       https://en.wikipedia.org//wiki/Zichron_Moshe           1
# 108       https://en.wikipedia.org//wiki/Zichron_Yosef           1
#
# [108 rows x 3 columns]

# %%
# merge by the same title and the same link
wiki_df = pd.merge(nbh_df, lop_df, how='outer')
wiki_df
# Out:
#                          titles  \
# 0                       Abu Tor
# 1    American Colony, Jerusalem
# 2              Armenian Quarter
# 3                        Arnona
# 4                  Arzei HaBira
# ..                          ...
# 174        San Simon, Jerusalem
# 175         Sanhedria Murchevet
# 176                     Unsdorf
# 177               Zichron Moshe
# 178               Zichron Yosef
#
#                                                  links  source_NoJ  source_LoP
# 0               https://en.wikipedia.org//wiki/Abu_Tor         1.0         1.0
# 1    https://en.wikipedia.org//wiki/American_Colony...         1.0         NaN
# 2      https://en.wikipedia.org//wiki/Armenian_Quarter         1.0         1.0
# 3                https://en.wikipedia.org//wiki/Arnona         1.0         1.0
# 4          https://en.wikipedia.org//wiki/Arzei_HaBira         1.0         NaN
# ..                                                 ...         ...         ...
# 174  https://en.wikipedia.org//wiki/San_Simon,_Jeru...         NaN         1.0
# 175  https://en.wikipedia.org//wiki/Sanhedria_Murch...         NaN         1.0
# 176             https://en.wikipedia.org//wiki/Unsdorf         NaN         1.0
# 177       https://en.wikipedia.org//wiki/Zichron_Moshe         NaN         1.0
# 178       https://en.wikipedia.org//wiki/Zichron_Yosef         NaN         1.0
#
# [179 rows x 4 columns]

# %%
####################################################################################
##### below deal with the same link and similar name

# %%
# same link in the wiki_df
fuzz_wiki_link = pd.DataFrame(data = [process.extract(str(item), wiki_df['links'], limit=3, 
        scorer=fuzz.ratio) for item in wiki_df['links']])

# %%
fuzz_wiki_link
# Out:
#                                                      0  \
# 0     (https://en.wikipedia.org//wiki/Abu_Tor, 100, 0)
# 1    (https://en.wikipedia.org//wiki/American_Colon...
# 2    (https://en.wikipedia.org//wiki/Armenian_Quart...
# 3      (https://en.wikipedia.org//wiki/Arnona, 100, 3)
# 4    (https://en.wikipedia.org//wiki/Arzei_HaBira, ...
# ..                                                 ...
# 174  (https://en.wikipedia.org//wiki/San_Simon,_Jer...
# 175  (https://en.wikipedia.org//wiki/Sanhedria_Murc...
# 176  (https://en.wikipedia.org//wiki/Unsdorf, 100, ...
# 177  (https://en.wikipedia.org//wiki/Zichron_Moshe,...
# 178  (https://en.wikipedia.org//wiki/Zichron_Yosef,...
#
#                                                      1  \
# 0       (https://en.wikipedia.org//wiki/Atarot, 91, 5)
# 1    (https://en.wikipedia.org//wiki/German_Colony,...
# 2    (https://en.wikipedia.org//wiki/Bukharan_Quart...
# 3     (https://en.wikipedia.org//wiki/Har_Nof, 93, 49)
# 4    (https://en.wikipedia.org//wiki/Rehavia, 91, 120)
# ..                                                 ...
# 174  (https://en.wikipedia.org//wiki/Ramot,_Jerusal...
# 175  (https://en.wikipedia.org//wiki/Sanhedria_Murh...
# 176  (https://en.wikipedia.org//wiki/Kiryat_Unsdorf...
# 177  (https://en.wikipedia.org//wiki/Zikhron_Moshe,...
# 178  (https://en.wikipedia.org//wiki/Zikhron_Yosef,...
#
#                                                      2
# 0    (https://en.wikipedia.org//wiki/Bab_Hutta, 90, 7)
# 1    (https://en.wikipedia.org//wiki/Greek_Colony,_...
# 2    (https://en.wikipedia.org//wiki/Christian_Quar...
# 3       (https://en.wikipedia.org//wiki/Atarot, 92, 5)
# 4    (https://en.wikipedia.org//wiki/Beit_Hanina, 8...
# ..                                                 ...
# 174  (https://en.wikipedia.org//wiki/Pat,_Jerusalem...
# 175  (https://en.wikipedia.org//wiki/Sanhedria, 89,...
# 176    (https://en.wikipedia.org//wiki/Abu_Tor, 89, 0)
# 177  (https://en.wikipedia.org//wiki/Zichron_Yosef,...
# 178  (https://en.wikipedia.org//wiki/Zichron_Moshe,...
#
# [179 rows x 3 columns]

# %%
fuzz_wiki_link[['name0', 'score0','index0']] = pd.DataFrame(fuzz_wiki_link[0].tolist(), index=fuzz_wiki_link.index)
fuzz_wiki_link[['name1', 'score1','index1']] = pd.DataFrame(fuzz_wiki_link[1].tolist(), index=fuzz_wiki_link.index)

# %%
fuzz_wiki_link = fuzz_wiki_link[fuzz_wiki_link['score1']>96]
fuzz_wiki_link
# Out:
#                                                      0  \
# 6    (https://en.wikipedia.org//wiki/Bab_az-Zahra, ...
# 28   (https://en.wikipedia.org//wiki/Ein_Karem, 100...
# 40   (https://en.wikipedia.org//wiki/Givat_Massuah,...
# 65   (https://en.wikipedia.org//wiki/Kiryat_HaYovel...
# 86   (https://en.wikipedia.org//wiki/Mea_Shearim, 1...
# 97   (https://en.wikipedia.org//wiki/Nahalat_Shiv%2...
# 108  (https://en.wikipedia.org//wiki/Al-Ram, 100, 108)
# 111  (https://en.wikipedia.org//wiki/Ramat_Eshkol, ...
# 125  (https://en.wikipedia.org//wiki/Sanhedria_Murh...
# 147  (https://en.wikipedia.org//wiki/Zikhron_Moshe,...
# 149  (https://en.wikipedia.org//wiki/Zikhron_Yosef,...
# 151  (https://en.wikipedia.org//wiki/Ar-Ram, 100, 151)
# 152  (https://en.wikipedia.org//wiki/Bab_a-Zahara, ...
# 154  (https://en.wikipedia.org//wiki/Ein_Kerem, 100...
# 156  (https://en.wikipedia.org//wiki/Givat_Masua, 1...
# 162  (https://en.wikipedia.org//wiki/Kiryat_HaYovel...
# 164  (https://en.wikipedia.org//wiki/Meah_Shearim, ...
# 167  (https://en.wikipedia.org//wiki/Nahalat_Shiva,...
# 172  (https://en.wikipedia.org//wiki/Ramot_Eshkol, ...
# 175  (https://en.wikipedia.org//wiki/Sanhedria_Murc...
# 177  (https://en.wikipedia.org//wiki/Zichron_Moshe,...
# 178  (https://en.wikipedia.org//wiki/Zichron_Yosef,...
#
#                                                      1  \
# 6    (https://en.wikipedia.org//wiki/Bab_a-Zahara, ...
# 28   (https://en.wikipedia.org//wiki/Ein_Kerem, 98,...
# 40   (https://en.wikipedia.org//wiki/Givat_Masua, 9...
# 65   (https://en.wikipedia.org//wiki/Kiryat_Hayovel...
# 86   (https://en.wikipedia.org//wiki/Meah_Shearim, ...
# 97   (https://en.wikipedia.org//wiki/Nahalat_Shiva,...
# 108   (https://en.wikipedia.org//wiki/Ar-Ram, 97, 151)
# 111  (https://en.wikipedia.org//wiki/Ramot_Eshkol, ...
# 125  (https://en.wikipedia.org//wiki/Sanhedria_Murc...
# 147  (https://en.wikipedia.org//wiki/Zichron_Moshe,...
# 149  (https://en.wikipedia.org//wiki/Zichron_Yosef,...
# 151   (https://en.wikipedia.org//wiki/Al-Ram, 97, 108)
# 152  (https://en.wikipedia.org//wiki/Bab_az-Zahra, ...
# 154  (https://en.wikipedia.org//wiki/Ein_Karem, 98,...
# 156  (https://en.wikipedia.org//wiki/Givat_Massuah,...
# 162  (https://en.wikipedia.org//wiki/Kiryat_Hayovel...
# 164  (https://en.wikipedia.org//wiki/Mea_Shearim, 9...
# 167  (https://en.wikipedia.org//wiki/Nahalat_Shiv%2...
# 172  (https://en.wikipedia.org//wiki/Ramat_Eshkol, ...
# 175  (https://en.wikipedia.org//wiki/Sanhedria_Murh...
# 177  (https://en.wikipedia.org//wiki/Zikhron_Moshe,...
# 178  (https://en.wikipedia.org//wiki/Zikhron_Yosef,...
#
#                                                      2  \
# 6     (https://en.wikipedia.org//wiki/Al-Ram, 88, 108)
# 28   (https://en.wikipedia.org//wiki/Tel_Arza, 89, ...
# 40   (https://en.wikipedia.org//wiki/Givat_Moshe, 9...
# 65   (https://en.wikipedia.org//wiki/Kiryat_HaLeom,...
# 86      (https://en.wikipedia.org//wiki/Malha, 90, 83)
# 97   (https://en.wikipedia.org//wiki/Nahalat_Shimon...
# 108     (https://en.wikipedia.org//wiki/Malha, 93, 83)
# 111  (https://en.wikipedia.org//wiki/Ramat_Shlomo, ...
# 125  (https://en.wikipedia.org//wiki/Sanhedria, 90,...
# 147  (https://en.wikipedia.org//wiki/Zikhron_Yosef,...
# 149  (https://en.wikipedia.org//wiki/Zikhron_Moshe,...
# 151    (https://en.wikipedia.org//wiki/Ramot, 93, 171)
# 152   (https://en.wikipedia.org//wiki/Al-Ram, 88, 108)
# 154  (https://en.wikipedia.org//wiki/Beit_Orot, 88,...
# 156  (https://en.wikipedia.org//wiki/Givat_HaMatos,...
# 162  (https://en.wikipedia.org//wiki/Kiryat_HaLeom,...
# 164     (https://en.wikipedia.org//wiki/Malha, 89, 83)
# 167  (https://en.wikipedia.org//wiki/Nahalat_Shimon...
# 172  (https://en.wikipedia.org//wiki/Ramot_Polin, 9...
# 175  (https://en.wikipedia.org//wiki/Sanhedria, 89,...
# 177  (https://en.wikipedia.org//wiki/Zichron_Yosef,...
# 178  (https://en.wikipedia.org//wiki/Zichron_Moshe,...
#
#                                                  name0  score0  index0  \
# 6          https://en.wikipedia.org//wiki/Bab_az-Zahra     100       6
# 28            https://en.wikipedia.org//wiki/Ein_Karem     100      28
# 40        https://en.wikipedia.org//wiki/Givat_Massuah     100      40
# 65       https://en.wikipedia.org//wiki/Kiryat_HaYovel     100      65
# 86          https://en.wikipedia.org//wiki/Mea_Shearim     100      86
# 97     https://en.wikipedia.org//wiki/Nahalat_Shiv%27a     100      97
# 108              https://en.wikipedia.org//wiki/Al-Ram     100     108
# 111        https://en.wikipedia.org//wiki/Ramat_Eshkol     100     111
# 125  https://en.wikipedia.org//wiki/Sanhedria_Murhevet     100     125
# 147       https://en.wikipedia.org//wiki/Zikhron_Moshe     100     147
# 149       https://en.wikipedia.org//wiki/Zikhron_Yosef     100     149
# 151              https://en.wikipedia.org//wiki/Ar-Ram     100     151
# 152        https://en.wikipedia.org//wiki/Bab_a-Zahara     100     152
# 154           https://en.wikipedia.org//wiki/Ein_Kerem     100     154
# 156         https://en.wikipedia.org//wiki/Givat_Masua     100     156
# 162      https://en.wikipedia.org//wiki/Kiryat_HaYovel     100      65
# 164        https://en.wikipedia.org//wiki/Meah_Shearim     100     164
# 167       https://en.wikipedia.org//wiki/Nahalat_Shiva     100     167
# 172        https://en.wikipedia.org//wiki/Ramot_Eshkol     100     172
# 175  https://en.wikipedia.org//wiki/Sanhedria_Murch...     100     175
# 177       https://en.wikipedia.org//wiki/Zichron_Moshe     100     177
# 178       https://en.wikipedia.org//wiki/Zichron_Yosef     100     178
#
#                                                  name1  score1  index1
# 6          https://en.wikipedia.org//wiki/Bab_a-Zahara      98     152
# 28            https://en.wikipedia.org//wiki/Ein_Kerem      98     154
# 40          https://en.wikipedia.org//wiki/Givat_Masua      98     156
# 65       https://en.wikipedia.org//wiki/Kiryat_Hayovel     100     162
# 86         https://en.wikipedia.org//wiki/Meah_Shearim      99     164
# 97        https://en.wikipedia.org//wiki/Nahalat_Shiva      97     167
# 108              https://en.wikipedia.org//wiki/Ar-Ram      97     151
# 111        https://en.wikipedia.org//wiki/Ramot_Eshkol      98     172
# 125  https://en.wikipedia.org//wiki/Sanhedria_Murch...      99     175
# 147       https://en.wikipedia.org//wiki/Zichron_Moshe      98     177
# 149       https://en.wikipedia.org//wiki/Zichron_Yosef      98     178
# 151              https://en.wikipedia.org//wiki/Al-Ram      97     108
# 152        https://en.wikipedia.org//wiki/Bab_az-Zahra      98       6
# 154           https://en.wikipedia.org//wiki/Ein_Karem      98      28
# 156       https://en.wikipedia.org//wiki/Givat_Massuah      98      40
# 162      https://en.wikipedia.org//wiki/Kiryat_Hayovel     100     162
# 164         https://en.wikipedia.org//wiki/Mea_Shearim      99      86
# 167    https://en.wikipedia.org//wiki/Nahalat_Shiv%27a      97      97
# 172        https://en.wikipedia.org//wiki/Ramat_Eshkol      98     111
# 175  https://en.wikipedia.org//wiki/Sanhedria_Murhevet      99     125
# 177       https://en.wikipedia.org//wiki/Zikhron_Moshe      98     147
# 178       https://en.wikipedia.org//wiki/Zikhron_Yosef      98     149

# %%
wiki_df.loc[wiki_df.index.isin(fuzz_wiki_link['index1'])]
# Out:
#                   titles                                              links  \
# 6           Bab az-Zahra        https://en.wikipedia.org//wiki/Bab_az-Zahra
# 28             Ein Karem           https://en.wikipedia.org//wiki/Ein_Karem
# 40         Givat Massuah       https://en.wikipedia.org//wiki/Givat_Massuah
# 86           Mea Shearim         https://en.wikipedia.org//wiki/Mea_Shearim
# 97        Nahalat Shiv'a    https://en.wikipedia.org//wiki/Nahalat_Shiv%27a
# 108               Al-Ram              https://en.wikipedia.org//wiki/Al-Ram
# 111         Ramat Eshkol        https://en.wikipedia.org//wiki/Ramat_Eshkol
# 125   Sanhedria Murhevet  https://en.wikipedia.org//wiki/Sanhedria_Murhevet
# 147        Zikhron Moshe       https://en.wikipedia.org//wiki/Zikhron_Moshe
# 149        Zikhron Yosef       https://en.wikipedia.org//wiki/Zikhron_Yosef
# 151               Ar-Ram              https://en.wikipedia.org//wiki/Ar-Ram
# 152         Bab a-Zahara        https://en.wikipedia.org//wiki/Bab_a-Zahara
# 154            Ein Kerem           https://en.wikipedia.org//wiki/Ein_Kerem
# 156          Givat Masua         https://en.wikipedia.org//wiki/Givat_Masua
# 162       Kiryat Hayovel      https://en.wikipedia.org//wiki/Kiryat_Hayovel
# 164         Meah Shearim        https://en.wikipedia.org//wiki/Meah_Shearim
# 167        Nahalat Shiva       https://en.wikipedia.org//wiki/Nahalat_Shiva
# 172         Ramot Eshkol        https://en.wikipedia.org//wiki/Ramot_Eshkol
# 175  Sanhedria Murchevet  https://en.wikipedia.org//wiki/Sanhedria_Murch...
# 177        Zichron Moshe       https://en.wikipedia.org//wiki/Zichron_Moshe
# 178        Zichron Yosef       https://en.wikipedia.org//wiki/Zichron_Yosef
#
#      source_NoJ  source_LoP
# 6           1.0         NaN
# 28          1.0         NaN
# 40          1.0         NaN
# 86          1.0         NaN
# 97          1.0         NaN
# 108         1.0         NaN
# 111         1.0         NaN
# 125         1.0         NaN
# 147         1.0         NaN
# 149         1.0         NaN
# 151         NaN         1.0
# 152         NaN         1.0
# 154         NaN         1.0
# 156         NaN         1.0
# 162         NaN         1.0
# 164         NaN         1.0
# 167         NaN         1.0
# 172         NaN         1.0
# 175         NaN         1.0
# 177         NaN         1.0
# 178         NaN         1.0

# %%
####################################################################################

# %%
wiki_df['coord_urls'], wiki_df['latitudes'], wiki_df['longitudes'] = get_coord(wiki_df['links'])
wiki_df
# Out:
#                          titles  \
# 0                       Abu Tor
# 1    American Colony, Jerusalem
# 2              Armenian Quarter
# 3                        Arnona
# 4                  Arzei HaBira
# ..                          ...
# 174        San Simon, Jerusalem
# 175         Sanhedria Murchevet
# 176                     Unsdorf
# 177               Zichron Moshe
# 178               Zichron Yosef
#
#                                                  links  source_NoJ  \
# 0               https://en.wikipedia.org//wiki/Abu_Tor         1.0
# 1    https://en.wikipedia.org//wiki/American_Colony...         1.0
# 2      https://en.wikipedia.org//wiki/Armenian_Quarter         1.0
# 3                https://en.wikipedia.org//wiki/Arnona         1.0
# 4          https://en.wikipedia.org//wiki/Arzei_HaBira         1.0
# ..                                                 ...         ...
# 174  https://en.wikipedia.org//wiki/San_Simon,_Jeru...         NaN
# 175  https://en.wikipedia.org//wiki/Sanhedria_Murch...         NaN
# 176             https://en.wikipedia.org//wiki/Unsdorf         NaN
# 177       https://en.wikipedia.org//wiki/Zichron_Moshe         NaN
# 178       https://en.wikipedia.org//wiki/Zichron_Yosef         NaN
#
#      source_LoP                                         coord_urls  \
# 0           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 1           NaN  //geohack.toolforge.org/geohack.php?pagename=A...
# 2           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 3           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 4           NaN  //geohack.toolforge.org/geohack.php?pagename=A...
# ..          ...                                                ...
# 174         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 175         1.0  //geohack.toolforge.org/geohack.php?pagename=S...
# 176         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 177         1.0  //geohack.toolforge.org/geohack.php?pagename=Z...
# 178         1.0  //geohack.toolforge.org/geohack.php?pagename=Z...
#
#          latitudes     longitudes
# 0     31°45′49.1″N   35°13′57.5″E
# 1       31°47′24″N     35°13′52″E
# 2       31°46′30″N     35°13′46″E
# 3          31°45′N        35°13′E
# 4    31°47′35.09″N  35°13′25.44″E
# ..             ...            ...
# 174     31°45′40″N     35°12′25″E
# 175     31°48′07″N     35°13′05″E
# 176     31°47′42″N     35°12′16″E
# 177     31°47′15″N     35°13′00″E
# 178     31°47′01″N     35°12′36″E
#
# [179 rows x 7 columns]

# %%
# translate to google coordinates
# all the coordinates are in North and East
wiki_df['latitudes_g'] = wiki_df['latitudes'].apply(lambda x: (float(x.split('°')[0])+
                                                    (float(x.split('°')[1].split('′')[0])/60  if ('′' in x)  else   0) +
                                                    (float(x.split('°')[1].split('′')[1].split('″')[0])/3600  if ('″' in x)  else   0)) if(x) else '-')

wiki_df['longitudes_g'] = wiki_df['longitudes'].apply(lambda x: (float(x.split('°')[0])+
                                                    (float(x.split('°')[1].split('′')[0])/60  if ('′' in x)  else   0) +
                                                    (float(x.split('°')[1].split('′')[1].split('″')[0])/3600  if ('″' in x)  else   0)) if(x) else '-')
wiki_df
# Out:
#                          titles  \
# 0                       Abu Tor
# 1    American Colony, Jerusalem
# 2              Armenian Quarter
# 3                        Arnona
# 4                  Arzei HaBira
# ..                          ...
# 174        San Simon, Jerusalem
# 175         Sanhedria Murchevet
# 176                     Unsdorf
# 177               Zichron Moshe
# 178               Zichron Yosef
#
#                                                  links  source_NoJ  \
# 0               https://en.wikipedia.org//wiki/Abu_Tor         1.0
# 1    https://en.wikipedia.org//wiki/American_Colony...         1.0
# 2      https://en.wikipedia.org//wiki/Armenian_Quarter         1.0
# 3                https://en.wikipedia.org//wiki/Arnona         1.0
# 4          https://en.wikipedia.org//wiki/Arzei_HaBira         1.0
# ..                                                 ...         ...
# 174  https://en.wikipedia.org//wiki/San_Simon,_Jeru...         NaN
# 175  https://en.wikipedia.org//wiki/Sanhedria_Murch...         NaN
# 176             https://en.wikipedia.org//wiki/Unsdorf         NaN
# 177       https://en.wikipedia.org//wiki/Zichron_Moshe         NaN
# 178       https://en.wikipedia.org//wiki/Zichron_Yosef         NaN
#
#      source_LoP                                         coord_urls  \
# 0           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 1           NaN  //geohack.toolforge.org/geohack.php?pagename=A...
# 2           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 3           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 4           NaN  //geohack.toolforge.org/geohack.php?pagename=A...
# ..          ...                                                ...
# 174         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 175         1.0  //geohack.toolforge.org/geohack.php?pagename=S...
# 176         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 177         1.0  //geohack.toolforge.org/geohack.php?pagename=Z...
# 178         1.0  //geohack.toolforge.org/geohack.php?pagename=Z...
#
#          latitudes     longitudes latitudes_g longitudes_g
# 0     31°45′49.1″N   35°13′57.5″E   31.763639    35.232639
# 1       31°47′24″N     35°13′52″E       31.79    35.231111
# 2       31°46′30″N     35°13′46″E      31.775    35.229444
# 3          31°45′N        35°13′E       31.75    35.216667
# 4    31°47′35.09″N  35°13′25.44″E   31.793081    35.223733
# ..             ...            ...         ...          ...
# 174     31°45′40″N     35°12′25″E   31.761111    35.206944
# 175     31°48′07″N     35°13′05″E   31.801944    35.218056
# 176     31°47′42″N     35°12′16″E      31.795    35.204444
# 177     31°47′15″N     35°13′00″E     31.7875    35.216667
# 178     31°47′01″N     35°12′36″E   31.783611        35.21
#
# [179 rows x 9 columns]

# %%
wiki_cor_df = wiki_df[~wiki_df['coord_urls'].isnull()]
wiki_cor_df
# Out:
#                          titles  \
# 0                       Abu Tor
# 1    American Colony, Jerusalem
# 2              Armenian Quarter
# 3                        Arnona
# 4                  Arzei HaBira
# ..                          ...
# 174        San Simon, Jerusalem
# 175         Sanhedria Murchevet
# 176                     Unsdorf
# 177               Zichron Moshe
# 178               Zichron Yosef
#
#                                                  links  source_NoJ  \
# 0               https://en.wikipedia.org//wiki/Abu_Tor         1.0
# 1    https://en.wikipedia.org//wiki/American_Colony...         1.0
# 2      https://en.wikipedia.org//wiki/Armenian_Quarter         1.0
# 3                https://en.wikipedia.org//wiki/Arnona         1.0
# 4          https://en.wikipedia.org//wiki/Arzei_HaBira         1.0
# ..                                                 ...         ...
# 174  https://en.wikipedia.org//wiki/San_Simon,_Jeru...         NaN
# 175  https://en.wikipedia.org//wiki/Sanhedria_Murch...         NaN
# 176             https://en.wikipedia.org//wiki/Unsdorf         NaN
# 177       https://en.wikipedia.org//wiki/Zichron_Moshe         NaN
# 178       https://en.wikipedia.org//wiki/Zichron_Yosef         NaN
#
#      source_LoP                                         coord_urls  \
# 0           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 1           NaN  //geohack.toolforge.org/geohack.php?pagename=A...
# 2           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 3           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 4           NaN  //geohack.toolforge.org/geohack.php?pagename=A...
# ..          ...                                                ...
# 174         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 175         1.0  //geohack.toolforge.org/geohack.php?pagename=S...
# 176         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 177         1.0  //geohack.toolforge.org/geohack.php?pagename=Z...
# 178         1.0  //geohack.toolforge.org/geohack.php?pagename=Z...
#
#          latitudes     longitudes latitudes_g longitudes_g
# 0     31°45′49.1″N   35°13′57.5″E   31.763639    35.232639
# 1       31°47′24″N     35°13′52″E       31.79    35.231111
# 2       31°46′30″N     35°13′46″E      31.775    35.229444
# 3          31°45′N        35°13′E       31.75    35.216667
# 4    31°47′35.09″N  35°13′25.44″E   31.793081    35.223733
# ..             ...            ...         ...          ...
# 174     31°45′40″N     35°12′25″E   31.761111    35.206944
# 175     31°48′07″N     35°13′05″E   31.801944    35.218056
# 176     31°47′42″N     35°12′16″E      31.795    35.204444
# 177     31°47′15″N     35°13′00″E     31.7875    35.216667
# 178     31°47′01″N     35°12′36″E   31.783611        35.21
#
# [163 rows x 9 columns]

# %%
result = wiki_cor_df[['titles','latitudes_g','longitudes_g']].to_json('wiki_cor.json',orient="records")

# %%
# find the exactly matched neighborhoods
perfect_match_df = pd.merge(book_df,wiki_cor_df,left_on=['Neighborhood'],right_on=['titles'])
perfect_match_df
# Out:
#             Neighborhood         Year founded  \
# 0   Mishkenot Sha'ananim            1855-1860
# 1         Mazkeret Moshe                 1882
# 2          Zikhron Tuvya                 1890
# 3            Yemin Moshe            1892-1894
# 4          Zikhron Moshe                 1906
# 5       Russian Compound            1858-1864
# 6                Mamilla  end of 19th century
# 7                Musrara   early 20th century
# 8                Talbiya   early 20th century
# 9                Talpiot                 1922
# 10               Rehavia                 1924
# 11             Sanhedria                 1926
# 12             Yefeh Nof                 1929
# 13         Kerem Avraham                 1930
# 14         Zikhron Yosef                 1931
# 15              Tel Arza                 1931
# 16                Arnona                 1931
# 17                Romema                 1922
#
#                              Inhabitants        Initiative  \
# 0                    Ashkenazi, Sephardi     Philanthropic
# 1                              Ashkenazi  Building society
# 2                                  Mixed        Commercial
# 3                    Sephardi, Ashkenazi  Building society
# 4                       mostly Ashkenazi  Building society
# 5                       Russian Orthodox     Philanthropic
# 6                                  Mixed           Private
# 7                        Christian Arabs           Private
# 8                        Christian Arabs           Private
# 9                 Bank clerks and others           Private
# 10                  Officials and clerks           Private
# 11              Mixed Jewish communities  Building society
# 12              Mixed Jewish communities           Private
# 13              Mixed Jewish communities           Private
# 14                               Kurdish           Private
# 15              Mixed Jewish communities           Private
# 16              Mixed Jewish communities           Private
# 17  Ashkenazi and Oriental Jews, Muslims           Private
#
#                                               Remarks Notes  source_book  \
# 0                                                 NaN   NaN            1
# 1                                                 NaN   NaN            1
# 2                                                 NaN   NaN            1
# 3                                                 NaN   NaN            1
# 4                                                 NaN   NaN            1
# 5                                                 NaN   NaN            1
# 6                                                 NaN   NaN            1
# 7                                                 NaN   NaN            1
# 8                                                 NaN   NaN            1
# 9       Garden-suburb; named after Song of Songs 4:4    NaN            1
# 10                                      Garden-suburb   NaN            1
# 11  Until 1929 one house was built by the Nahalat ...   NaN            1
# 12  Loose neighborhood organization; named after P...   NaN            1
# 13  Loose neighborhood organization; named by Jame...   NaN            1
# 14  Loose neighborhood organization; high density;...   NaN            1
# 15                                                NaN   NaN            1
# 16  Named after the Arnon Gorge across the Dead Se...   NaN            1
# 17                          Named after Psalms 118:16   NaN            1
#
#                   titles                                              links  \
# 0   Mishkenot Sha'ananim  https://en.wikipedia.org//wiki/Mishkenot_Sha%2...
# 1         Mazkeret Moshe      https://en.wikipedia.org//wiki/Mazkeret_Moshe
# 2          Zikhron Tuvya       https://en.wikipedia.org//wiki/Zikhron_Tuvya
# 3            Yemin Moshe         https://en.wikipedia.org//wiki/Yemin_Moshe
# 4          Zikhron Moshe       https://en.wikipedia.org//wiki/Zikhron_Moshe
# 5       Russian Compound    https://en.wikipedia.org//wiki/Russian_Compound
# 6                Mamilla             https://en.wikipedia.org//wiki/Mamilla
# 7                Musrara             https://en.wikipedia.org//wiki/Musrara
# 8                Talbiya             https://en.wikipedia.org//wiki/Talbiya
# 9                Talpiot             https://en.wikipedia.org//wiki/Talpiot
# 10               Rehavia             https://en.wikipedia.org//wiki/Rehavia
# 11             Sanhedria           https://en.wikipedia.org//wiki/Sanhedria
# 12             Yefeh Nof           https://en.wikipedia.org//wiki/Yefeh_Nof
# 13         Kerem Avraham       https://en.wikipedia.org//wiki/Kerem_Avraham
# 14         Zikhron Yosef       https://en.wikipedia.org//wiki/Zikhron_Yosef
# 15              Tel Arza            https://en.wikipedia.org//wiki/Tel_Arza
# 16                Arnona              https://en.wikipedia.org//wiki/Arnona
# 17                Romema              https://en.wikipedia.org//wiki/Romema
#
#     source_NoJ  source_LoP                                         coord_urls  \
# 0          1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=M...
# 1          1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=M...
# 2          1.0         NaN  //geohack.toolforge.org/geohack.php?pagename=Z...
# 3          1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=Y...
# 4          1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=Z...
# 5          1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=R...
# 6          1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=M...
# 7          1.0         NaN  //geohack.toolforge.org/geohack.php?pagename=M...
# 8          1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=T...
# 9          1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=T...
# 10         1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=R...
# 11         1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=S...
# 12         1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=Y...
# 13         1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 14         1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=Z...
# 15         1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=T...
# 16         1.0         1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 17         1.0         NaN  //geohack.toolforge.org/geohack.php?pagename=R...
#
#         latitudes     longitudes latitudes_g longitudes_g
# 0   31°46′17.05″N  35°13′27.65″E   31.771403    35.224347
# 1      31°46′59″N     35°12′50″E   31.783056    35.213889
# 2   31°46′59.93″N  35°12′43.71″E   31.783314    35.212142
# 3      31°46′19″N     35°13′30″E   31.771944       35.225
# 4      31°47′15″N     35°13′00″E     31.7875    35.216667
# 5   31°46′55.47″N  35°13′18.17″E   31.782075    35.221714
# 6   31°46′34.02″N  35°13′24.44″E   31.776117    35.223456
# 7      31°46′57″N     35°13′32″E     31.7825    35.225556
# 8         31°46′N        35°13′E   31.766667    35.216667
# 9         31°45′N        35°13′E       31.75    35.216667
# 10  31°46′28.11″N  35°12′43.19″E   31.774475    35.211997
# 11     31°47′54″N     35°13′15″E   31.798333    35.220833
# 12     31°46′45″N     35°11′11″E   31.779167    35.186389
# 13     31°47′24″N      35°13′2″E       31.79    35.217222
# 14     31°47′01″N     35°12′36″E   31.783611        35.21
# 15     31°47′42″N     35°12′55″E      31.795    35.215278
# 16        31°45′N        35°13′E       31.75    35.216667
# 17     31°47′24″N     35°12′14″E       31.79    35.203889

# %%
# see results
result = perfect_match_df.to_json('perfect_match.json',orient="records")

# %%
# left items in book
book_left_df = book_df[~book_df['Neighborhood'].isin(perfect_match_df['Neighborhood'])]
book_left_df = book_left_df.reset_index()
book_left_df
# Out:
#      index                     Neighborhood    Year founded  \
# 0        1                 Mahaneh Yisra’el            1866
# 1        2                   Nanalat Shiv’a            1869
# 2        3  Georgian Houses (Eshel Avraham)       1872-1876
# 3        4       Bet David (Yanover Houses)            1873
# 4        5                   Me'ah She'arim            1875
# ..     ...                              ...             ...
# 142    159                      Wadi Haluwa  End of Mandate
# 143    161                          Dajania   Early Mandate
# 144    162                     al-Musallaba   Early Mandate
# 145    163                   St. Louis Road   Early Mandate
# 146    164                    Macrae Estate          1930s?
#
#                    Inhabitants                    Initiative  \
# 0                   Maghrebian                       Private
# 1          Ashkenazi, Sephardi                       Private
# 2                     Georgian  Building society and private
# 3                    Ashkenazi                 Philanthropic
# 4                    Ashkenazi              Building society
# ..                         ...                           ...
# 142                    Muslims                           NaN
# 143        Muslims, Christians                       Private
# 144        Mixed (mainly Jews)                           NaN
# 145  Jews, Muslims, Christians                           NaN
# 146              Jews, Muslims                       Private
#
#               Remarks Notes  source_book
# 0                 NaN   NaN            1
# 1                 NaN   NaN            1
# 2                 NaN   NaN            1
# 3                 NaN   NaN            1
# 4                 NaN   NaN            1
# ..                ...   ...          ...
# 142               NaN   NaN            1
# 143               NaN     *            1
# 144  Part of Rehavia?   NaN            1
# 145               NaN     *            1
# 146      Near Rehavia   NaN            1
#
# [147 rows x 8 columns]

# %%
# left items in wiki
wiki_left_df = wiki_cor_df[~wiki_df['titles'].isin(perfect_match_df['titles'])]
wiki_left_df = wiki_left_df.reset_index()
wiki_left_df
# Out:
#      index                      titles  \
# 0        0                     Abu Tor
# 1        1  American Colony, Jerusalem
# 2        2            Armenian Quarter
# 3        4                Arzei HaBira
# 4        5                      Atarot
# ..     ...                         ...
# 128    162            Moroccan Quarter
# 129    163                       Ramot
# 130    164           Romema, Jerusalem
# 131    165        San Simon, Jerusalem
# 132    166                     Unsdorf
#
#                                                  links  source_NoJ  \
# 0               https://en.wikipedia.org//wiki/Abu_Tor         1.0
# 1    https://en.wikipedia.org//wiki/American_Colony...         1.0
# 2      https://en.wikipedia.org//wiki/Armenian_Quarter         1.0
# 3          https://en.wikipedia.org//wiki/Arzei_HaBira         1.0
# 4                https://en.wikipedia.org//wiki/Atarot         1.0
# ..                                                 ...         ...
# 128    https://en.wikipedia.org//wiki/Moroccan_Quarter         NaN
# 129               https://en.wikipedia.org//wiki/Ramot         NaN
# 130   https://en.wikipedia.org//wiki/Romema,_Jerusalem         NaN
# 131  https://en.wikipedia.org//wiki/San_Simon,_Jeru...         NaN
# 132             https://en.wikipedia.org//wiki/Unsdorf         NaN
#
#      source_LoP                                         coord_urls  \
# 0           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 1           NaN  //geohack.toolforge.org/geohack.php?pagename=A...
# 2           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# 3           NaN  //geohack.toolforge.org/geohack.php?pagename=A...
# 4           1.0  //geohack.toolforge.org/geohack.php?pagename=A...
# ..          ...                                                ...
# 128         1.0  //geohack.toolforge.org/geohack.php?pagename=M...
# 129         1.0  //geohack.toolforge.org/geohack.php?pagename=R...
# 130         1.0  //geohack.toolforge.org/geohack.php?pagename=R...
# 131         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 132         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
#
#          latitudes     longitudes latitudes_g longitudes_g
# 0     31°45′49.1″N   35°13′57.5″E   31.763639    35.232639
# 1       31°47′24″N     35°13′52″E       31.79    35.231111
# 2       31°46′30″N     35°13′46″E      31.775    35.229444
# 3    31°47′35.09″N  35°13′25.44″E   31.793081    35.223733
# 4          31°51′N        35°13′E       31.85    35.216667
# ..             ...            ...         ...          ...
# 128     31°46′36″N      35°14′3″E   31.776667    35.234167
# 129     31°48′43″N      35°12′0″E   31.811944         35.2
# 130     31°47′24″N     35°12′14″E       31.79    35.203889
# 131     31°45′40″N     35°12′25″E   31.761111    35.206944
# 132     31°47′42″N     35°12′16″E      31.795    35.204444
#
# [133 rows x 10 columns]

# %%
# match the left data

fuzz_match_df = pd.concat([book_left_df['Neighborhood'],pd.DataFrame(data = [process.extract(str(item), wiki_left_df['titles'], limit=3, 
        scorer=fuzz.ratio) for item in book_left_df['Neighborhood']], columns=['sub1','sub2','sub3'])],axis= 1)
fuzz_match_df
# Out:
#                         Neighborhood                               sub1  \
# 0                   Mahaneh Yisra’el            (Mahane Israel, 90, 71)
# 1                     Nanalat Shiv’a           (Nahalat Shiv'a, 93, 83)
# 2    Georgian Houses (Eshel Avraham)          (Givat HaVradim, 45, 121)
# 3         Bet David (Yanover Houses)  (Beit Ya'akov, Jerusalem, 54, 18)
# 4                     Me'ah She'arim              (Mea Shearim, 88, 74)
# ..                               ...                                ...
# 142                      Wadi Haluwa             (Wadi Hilweh, 73, 117)
# 143                          Dajania            (Mahane Israel, 50, 71)
# 144                     al-Musallaba               (Al-Walaja, 67, 118)
# 145                   St. Louis Road          (Knesset Yisrael, 48, 67)
# 146                    Macrae Estate          (Sha'arei Hesed, 52, 105)
#
#                           sub2                                 sub3
# 0    (Knesset Yisrael, 65, 67)               (Beit Yisrael, 64, 19)
# 1     (Nahalat Shimon, 71, 82)              (Ramat Sharett, 52, 98)
# 2        (Mea Shearim, 44, 74)   (German Colony, Jerusalem, 41, 31)
# 3         (Beit David, 51, 13)    (Beit HaKerem, Jerusalem, 50, 14)
# 4      (Ramat Sharett, 52, 98)             (Nahalat Shimon, 50, 82)
# ..                         ...                                  ...
# 142     (Wadi al-Joz, 64, 116)                (Arzei HaBira, 52, 3)
# 143      (Beit Hanina, 44, 15)               (Al-Issawiya, 44, 123)
# 144    (Jabel Mukaber, 56, 49)               (Al-Issawiya, 52, 123)
# 145     (Beit Yisrael, 46, 19)              (Ezrat Yisrael, 44, 29)
# 146  (Ma'ale HaZeitim, 50, 69)  (Sharafat, East Jerusalem, 49, 107)
#
# [147 rows x 4 columns]

# %%
fuzz_match_df[['name1', 'score1','index1']] = pd.DataFrame(fuzz_match_df['sub1'].tolist(), index=fuzz_match_df.index)
fuzz_match_df[['name2', 'score2','index2']] = pd.DataFrame(fuzz_match_df['sub2'].tolist(), index=fuzz_match_df.index)
fuzz_match_df[['name3', 'score3','index3']] = pd.DataFrame(fuzz_match_df['sub3'].tolist(), index=fuzz_match_df.index)

# %%
# find scores more than 70
fuzz_match_df[(fuzz_match_df['score1']>70)|(fuzz_match_df['score2']>70)|(fuzz_match_df['score3']>70)]
# Out:
#                              Neighborhood                              sub1  \
# 0                        Mahaneh Yisra’el           (Mahane Israel, 90, 71)
# 1                          Nanalat Shiv’a          (Nahalat Shiv'a, 93, 83)
# 4                          Me'ah She'arim             (Mea Shearim, 88, 74)
# 5                           Even Yisra’el            (Beit Yisrael, 72, 19)
# 9                             Bet Ya'akov             (Neve Yaakov, 73, 87)
# 14                     (Old) Bet Yisra'el            (Beit Yisrael, 76, 19)
# 20                        Sha'arei Tzedeq         (Sha'arei Hesed, 76, 105)
# 24                Shim'on haTzadiq Houses        (Shimon HaTzadik, 74, 111)
# 26   Sha'arei Yerushalayim (“Abu-Bassal”)  (Sha'arei Yerushalayim, 76, 106)
# 27                        ‘Ezrat Yisra'el           (Ezrat Yisrael, 96, 29)
# 29                        Nahalat Shim'on          (Nahalat Shimon, 97, 82)
# 31                           Kerem Shlomo            (Ramat Shlomo, 75, 99)
# 41                   Old Knesset Yisrae’l         (Knesset Yisrael, 86, 67)
# 42                         Nahalat Tziyon          (Nahalat Shimon, 79, 82)
# 55                         Nahalat Tziyon          (Nahalat Shimon, 79, 82)
# 64                       Sha’ arei Hessed         (Sha'arei Hesed, 93, 105)
# 67                        Giv'at Sha'ul A             (Givat Shaul, 85, 41)
# 71                       New Bet Yisra’el            (Beit Yisrael, 79, 19)
# 76                           Deir Abu-Tor                  (Abu Tor, 74, 0)
# 80                          Bab al-Sahira             (Bab az-Zahra, 80, 5)
# 86                  Wadi al-Joz (al-Oa'a)            (Wadi al-Joz, 71, 116)
# 92                                Qatamon                 (Katamon, 86, 55)
# 93                            Bet haKerem      (Givat Beit HaKerem, 76, 34)
# 94                           Megor Hayyim             (Mekor Chaim, 78, 76)
# 97                           Nahalat Ahim          (Nahalat Shimon, 85, 82)
# 99                                Ge'ulah                   (Geula, 83, 32)
# 103                          Bayit ve-Gan             (Bayit VeGan, 96, 12)
# 106                       Giv'at Sha'ul B             (Givat Shaul, 85, 41)
# 111                          Meqor Barukh            (Mekor Baruch, 83, 75)
# 119                         North Talpiot            (East Talpiot, 72, 24)
# 133                           Shaikh Badr            (Sheikh Badr, 91, 108)
# 137                           al-Karamein                  (Al-Ram, 71, 93)
# 142                           Wadi Haluwa            (Wadi Hilweh, 73, 117)
#
#                                      sub2                               sub3  \
# 0               (Knesset Yisrael, 65, 67)             (Beit Yisrael, 64, 19)
# 1                (Nahalat Shimon, 71, 82)            (Ramat Sharett, 52, 98)
# 4                 (Ramat Sharett, 52, 98)           (Nahalat Shimon, 50, 82)
# 5               (Knesset Yisrael, 71, 67)            (Ezrat Yisrael, 69, 29)
# 9       (Beit Ya'akov, Jerusalem, 65, 18)               (Beit David, 57, 13)
# 14                (Ezrat Yisrael, 67, 29)          (Knesset Yisrael, 62, 67)
# 20       (Sha'arei Yerushalayim, 56, 106)            (Har Hazeitim, 52, 124)
# 24               (Shikun Chabad, 50, 110)    (San Simon, Jerusalem, 47, 131)
# 26   (Jewish Quarter (Jerusalem), 47, 53)          (Sha'arei Hesed, 46, 105)
# 27                 (Beit Yisrael, 77, 19)          (Knesset Yisrael, 69, 67)
# 29               (Nahalat Shiv'a, 83, 83)             (Ramat Shlomo, 59, 99)
# 31      (Beit HaKerem, Jerusalem, 51, 14)                 (Har Homa, 50, 43)
# 41                 (Beit Yisrael, 62, 19)            (Ezrat Yisrael, 61, 29)
# 42               (Nahalat Shiv'a, 64, 83)              (Mount Zion, 58, 119)
# 55               (Nahalat Shiv'a, 64, 83)              (Mount Zion, 58, 119)
# 64       (Sha'arei Yerushalayim, 54, 106)      (Sanhedria Murhevet, 47, 104)
# 67                (Givat HaMatos, 64, 35)           (Givat HaMivtar, 62, 36)
# 71              (Knesset Yisrael, 77, 67)            (Ezrat Yisrael, 69, 29)
# 76                  (Ezrat Torah, 61, 28)             (Wadi al-Joz, 52, 116)
# 80                 (Al-Issawiya, 58, 123)            (Ma'alot Dafna, 54, 70)
# 86                   (Al-Walaja, 48, 118)              (Bab az-Zahra, 44, 5)
# 92                        (Atarot, 62, 4)            (Givat HaMatos, 50, 35)
# 93           (Ramat Beit HaKerem, 76, 94)  (Beit HaKerem, Jerusalem, 65, 14)
# 94                  (Emek Refaim, 52, 26)          (Ma'ale HaZeitim, 52, 69)
# 97               (Nahalat Shiv'a, 77, 83)                 (Nachlaot, 60, 81)
# 99                (Givat Massuah, 50, 37)              (Ezrat Torah, 44, 28)
# 103               (Batei Ungarin, 56, 10)              (Beit Hanina, 52, 15)
# 106                   (Givat Ram, 58, 40)            (Givat HaMatos, 57, 35)
# 111                 (Mekor Chaim, 52, 76)               (Sur Baher, 48, 113)
# 119                    (Nachlaot, 48, 81)                 (Nof Zion, 48, 88)
# 133              (Sheikh Jarrah, 67, 109)           (Shikun Chabad, 67, 110)
# 137                     (Katamon, 56, 55)            (Batei Ungarin, 50, 10)
# 142                (Wadi al-Joz, 64, 116)              (Arzei HaBira, 52, 3)
#
#                      name1  score1  index1                       name2  \
# 0            Mahane Israel      90      71             Knesset Yisrael
# 1           Nahalat Shiv'a      93      83              Nahalat Shimon
# 4              Mea Shearim      88      74               Ramat Sharett
# 5             Beit Yisrael      72      19             Knesset Yisrael
# 9              Neve Yaakov      73      87     Beit Ya'akov, Jerusalem
# 14            Beit Yisrael      76      19               Ezrat Yisrael
# 20          Sha'arei Hesed      76     105       Sha'arei Yerushalayim
# 24         Shimon HaTzadik      74     111               Shikun Chabad
# 26   Sha'arei Yerushalayim      76     106  Jewish Quarter (Jerusalem)
# 27           Ezrat Yisrael      96      29                Beit Yisrael
# 29          Nahalat Shimon      97      82              Nahalat Shiv'a
# 31            Ramat Shlomo      75      99     Beit HaKerem, Jerusalem
# 41         Knesset Yisrael      86      67                Beit Yisrael
# 42          Nahalat Shimon      79      82              Nahalat Shiv'a
# 55          Nahalat Shimon      79      82              Nahalat Shiv'a
# 64          Sha'arei Hesed      93     105       Sha'arei Yerushalayim
# 67             Givat Shaul      85      41               Givat HaMatos
# 71            Beit Yisrael      79      19             Knesset Yisrael
# 76                 Abu Tor      74       0                 Ezrat Torah
# 80            Bab az-Zahra      80       5                 Al-Issawiya
# 86             Wadi al-Joz      71     116                   Al-Walaja
# 92                 Katamon      86      55                      Atarot
# 93      Givat Beit HaKerem      76      34          Ramat Beit HaKerem
# 94             Mekor Chaim      78      76                 Emek Refaim
# 97          Nahalat Shimon      85      82              Nahalat Shiv'a
# 99                   Geula      83      32               Givat Massuah
# 103            Bayit VeGan      96      12               Batei Ungarin
# 106            Givat Shaul      85      41                   Givat Ram
# 111           Mekor Baruch      83      75                 Mekor Chaim
# 119           East Talpiot      72      24                    Nachlaot
# 133            Sheikh Badr      91     108               Sheikh Jarrah
# 137                 Al-Ram      71      93                     Katamon
# 142            Wadi Hilweh      73     117                 Wadi al-Joz
#
#      score2  index2                    name3  score3  index3
# 0        65      67             Beit Yisrael      64      19
# 1        71      82            Ramat Sharett      52      98
# 4        52      98           Nahalat Shimon      50      82
# 5        71      67            Ezrat Yisrael      69      29
# 9        65      18               Beit David      57      13
# 14       67      29          Knesset Yisrael      62      67
# 20       56     106             Har Hazeitim      52     124
# 24       50     110     San Simon, Jerusalem      47     131
# 26       47      53           Sha'arei Hesed      46     105
# 27       77      19          Knesset Yisrael      69      67
# 29       83      83             Ramat Shlomo      59      99
# 31       51      14                 Har Homa      50      43
# 41       62      19            Ezrat Yisrael      61      29
# 42       64      83               Mount Zion      58     119
# 55       64      83               Mount Zion      58     119
# 64       54     106       Sanhedria Murhevet      47     104
# 67       64      35           Givat HaMivtar      62      36
# 71       77      67            Ezrat Yisrael      69      29
# 76       61      28              Wadi al-Joz      52     116
# 80       58     123            Ma'alot Dafna      54      70
# 86       48     118             Bab az-Zahra      44       5
# 92       62       4            Givat HaMatos      50      35
# 93       76      94  Beit HaKerem, Jerusalem      65      14
# 94       52      26          Ma'ale HaZeitim      52      69
# 97       77      83                 Nachlaot      60      81
# 99       50      37              Ezrat Torah      44      28
# 103      56      10              Beit Hanina      52      15
# 106      58      40            Givat HaMatos      57      35
# 111      52      76                Sur Baher      48     113
# 119      48      81                 Nof Zion      48      88
# 133      67     109            Shikun Chabad      67     110
# 137      56      55            Batei Ungarin      50      10
# 142      64     116             Arzei HaBira      52       3

# %%
fuzz_match_df
# Out:
#                         Neighborhood                               sub1  \
# 0                   Mahaneh Yisra’el            (Mahane Israel, 90, 71)
# 1                     Nanalat Shiv’a           (Nahalat Shiv'a, 93, 83)
# 2    Georgian Houses (Eshel Avraham)          (Givat HaVradim, 45, 121)
# 3         Bet David (Yanover Houses)  (Beit Ya'akov, Jerusalem, 54, 18)
# 4                     Me'ah She'arim              (Mea Shearim, 88, 74)
# ..                               ...                                ...
# 142                      Wadi Haluwa             (Wadi Hilweh, 73, 117)
# 143                          Dajania            (Mahane Israel, 50, 71)
# 144                     al-Musallaba               (Al-Walaja, 67, 118)
# 145                   St. Louis Road          (Knesset Yisrael, 48, 67)
# 146                    Macrae Estate          (Sha'arei Hesed, 52, 105)
#
#                           sub2                                 sub3  \
# 0    (Knesset Yisrael, 65, 67)               (Beit Yisrael, 64, 19)
# 1     (Nahalat Shimon, 71, 82)              (Ramat Sharett, 52, 98)
# 2        (Mea Shearim, 44, 74)   (German Colony, Jerusalem, 41, 31)
# 3         (Beit David, 51, 13)    (Beit HaKerem, Jerusalem, 50, 14)
# 4      (Ramat Sharett, 52, 98)             (Nahalat Shimon, 50, 82)
# ..                         ...                                  ...
# 142     (Wadi al-Joz, 64, 116)                (Arzei HaBira, 52, 3)
# 143      (Beit Hanina, 44, 15)               (Al-Issawiya, 44, 123)
# 144    (Jabel Mukaber, 56, 49)               (Al-Issawiya, 52, 123)
# 145     (Beit Yisrael, 46, 19)              (Ezrat Yisrael, 44, 29)
# 146  (Ma'ale HaZeitim, 50, 69)  (Sharafat, East Jerusalem, 49, 107)
#
#                        name1  score1  index1            name2  score2  index2  \
# 0              Mahane Israel      90      71  Knesset Yisrael      65      67
# 1             Nahalat Shiv'a      93      83   Nahalat Shimon      71      82
# 2             Givat HaVradim      45     121      Mea Shearim      44      74
# 3    Beit Ya'akov, Jerusalem      54      18       Beit David      51      13
# 4                Mea Shearim      88      74    Ramat Sharett      52      98
# ..                       ...     ...     ...              ...     ...     ...
# 142              Wadi Hilweh      73     117      Wadi al-Joz      64     116
# 143            Mahane Israel      50      71      Beit Hanina      44      15
# 144                Al-Walaja      67     118    Jabel Mukaber      56      49
# 145          Knesset Yisrael      48      67     Beit Yisrael      46      19
# 146           Sha'arei Hesed      52     105  Ma'ale HaZeitim      50      69
#
#                         name3  score3  index3
# 0                Beit Yisrael      64      19
# 1               Ramat Sharett      52      98
# 2    German Colony, Jerusalem      41      31
# 3     Beit HaKerem, Jerusalem      50      14
# 4              Nahalat Shimon      50      82
# ..                        ...     ...     ...
# 142              Arzei HaBira      52       3
# 143               Al-Issawiya      44     123
# 144               Al-Issawiya      52     123
# 145             Ezrat Yisrael      44      29
# 146  Sharafat, East Jerusalem      49     107
#
# [147 rows x 13 columns]

# %%
# fuzz_match_df.loc['partial_score1'] = fuzz_match_df.apply(lambda x:fuzz.partial_ratio(book_left_df['Neighborhood'],x['name1']), axis=0)
# fuzz_match_df

# %%
book_df = book_df[~book_df['Neighborhood'].isnull()]

# %%
# whole dataset after perfect match 
wiki_temp_df = wiki_cor_df.rename(columns={'titles':'Neighborhood'})
total_list_permatch = pd.merge(book_df,wiki_temp_df,how = 'outer')
total_list_permatch
# Out:
#                         Neighborhood Original_year_info  Year_founded  \
# 0               Mishkenot Sha'ananim          1855-1860        1855.0
# 1                   Mahaneh Yisra’el               1866        1866.0
# 2                     Nanalat Shiv’a               1869        1869.0
# 3    Georgian Houses (Eshel Avraham)          1872-1876        1872.0
# 4         Bet David (Yanover Houses)               1873        1873.0
# ..                               ...                ...           ...
# 305             San Simon, Jerusalem                NaN           NaN
# 306              Sanhedria Murchevet                NaN           NaN
# 307                          Unsdorf                NaN           NaN
# 308                    Zichron Moshe                NaN           NaN
# 309                    Zichron Yosef                NaN           NaN
#
#              Inhabitants                    Initiative Remarks  \
# 0    Ashkenazi, Sephardi                 Philanthropic     NaN
# 1             Maghrebian                       Private     NaN
# 2    Ashkenazi, Sephardi                       Private     NaN
# 3               Georgian  Building society and private     NaN
# 4              Ashkenazi                 Philanthropic     NaN
# ..                   ...                           ...     ...
# 305                  NaN                           NaN     NaN
# 306                  NaN                           NaN     NaN
# 307                  NaN                           NaN     NaN
# 308                  NaN                           NaN     NaN
# 309                  NaN                           NaN     NaN
#
#                Type of neighborhood  source_book  \
# 0    Jewish and mixed neighborhoods          1.0
# 1    Jewish and mixed neighborhoods          1.0
# 2    Jewish and mixed neighborhoods          1.0
# 3    Jewish and mixed neighborhoods          1.0
# 4    Jewish and mixed neighborhoods          1.0
# ..                              ...          ...
# 305                             NaN          NaN
# 306                             NaN          NaN
# 307                             NaN          NaN
# 308                             NaN          NaN
# 309                             NaN          NaN
#
#                                                  links  source_NoJ  \
# 0    https://en.wikipedia.org//wiki/Mishkenot_Sha%2...         1.0
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 305  https://en.wikipedia.org//wiki/San_Simon,_Jeru...         NaN
# 306  https://en.wikipedia.org//wiki/Sanhedria_Murch...         NaN
# 307             https://en.wikipedia.org//wiki/Unsdorf         NaN
# 308       https://en.wikipedia.org//wiki/Zichron_Moshe         NaN
# 309       https://en.wikipedia.org//wiki/Zichron_Yosef         NaN
#
#      source_LoP                                         coord_urls  \
# 0           1.0  //geohack.toolforge.org/geohack.php?pagename=M...
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# ..          ...                                                ...
# 305         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 306         1.0  //geohack.toolforge.org/geohack.php?pagename=S...
# 307         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 308         1.0  //geohack.toolforge.org/geohack.php?pagename=Z...
# 309         1.0  //geohack.toolforge.org/geohack.php?pagename=Z...
#
#          latitudes     longitudes latitudes_g longitudes_g
# 0    31°46′17.05″N  35°13′27.65″E   31.771403    35.224347
# 1              NaN            NaN         NaN          NaN
# 2              NaN            NaN         NaN          NaN
# 3              NaN            NaN         NaN          NaN
# 4              NaN            NaN         NaN          NaN
# ..             ...            ...         ...          ...
# 305     31°45′40″N     35°12′25″E   31.761111    35.206944
# 306     31°48′07″N     35°13′05″E   31.801944    35.218056
# 307     31°47′42″N     35°12′16″E      31.795    35.204444
# 308     31°47′15″N     35°13′00″E     31.7875    35.216667
# 309     31°47′01″N     35°12′36″E   31.783611        35.21
#
# [310 rows x 16 columns]

# %%
total_list_permatch.to_csv('./total_list_permatch_2.0.csv',index = False)

# %%
# do the matches manually

# %%
# results
df = pd.read_csv('./total_list_permatch_3.0.csv')

# %%
df
# Out:
#                         Neighborhood Original_year_info  Year_founded  \
# 0               Mishkenot Sha'ananim          1855-1860        1855.0
# 1                   Mahaneh Yisra’el               1866        1866.0
# 2                     Nanalat Shiv’a               1869        1869.0
# 3    Georgian Houses (Eshel Avraham)          1872-1876        1872.0
# 4         Bet David (Yanover Houses)               1873        1873.0
# ..                               ...                ...           ...
# 281                 Moroccan Quarter                NaN           NaN
# 282                            Ramot                NaN           NaN
# 283                Romema, Jerusalem                NaN           NaN
# 284             San Simon, Jerusalem                NaN           NaN
# 285                          Unsdorf                NaN           NaN
#
#              Inhabitants                    Initiative Remarks  \
# 0    Ashkenazi, Sephardi                 Philanthropic     NaN
# 1             Maghrebian                       Private     NaN
# 2    Ashkenazi, Sephardi                       Private     NaN
# 3               Georgian  Building society and private     NaN
# 4              Ashkenazi                 Philanthropic     NaN
# ..                   ...                           ...     ...
# 281                  NaN                           NaN     NaN
# 282                  NaN                           NaN     NaN
# 283                  NaN                           NaN     NaN
# 284                  NaN                           NaN     NaN
# 285                  NaN                           NaN     NaN
#
#                Type of neighborhood  source_book  \
# 0    Jewish and mixed neighborhoods          1.0
# 1    Jewish and mixed neighborhoods          1.0
# 2    Jewish and mixed neighborhoods          1.0
# 3    Jewish and mixed neighborhoods          1.0
# 4    Jewish and mixed neighborhoods          1.0
# ..                              ...          ...
# 281                             NaN          NaN
# 282                             NaN          NaN
# 283                             NaN          NaN
# 284                             NaN          NaN
# 285                             NaN          NaN
#
#                                                  links  source_NoJ  \
# 0    https://en.wikipedia.org//wiki/Mishkenot_Sha%2...         1.0
# 1         https://en.wikipedia.org//wiki/Mahane_Israel         1.0
# 2      https://en.wikipedia.org//wiki/Nahalat_Shiv%27a         1.0
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 281    https://en.wikipedia.org//wiki/Moroccan_Quarter         NaN
# 282               https://en.wikipedia.org//wiki/Ramot         NaN
# 283   https://en.wikipedia.org//wiki/Romema,_Jerusalem         NaN
# 284  https://en.wikipedia.org//wiki/San_Simon,_Jeru...         NaN
# 285             https://en.wikipedia.org//wiki/Unsdorf         NaN
#
#      source_LoP                                         coord_urls  \
# 0           1.0  //geohack.toolforge.org/geohack.php?pagename=M...
# 1           1.0  //geohack.toolforge.org/geohack.php?pagename=M...
# 2           1.0  //geohack.toolforge.org/geohack.php?pagename=N...
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# ..          ...                                                ...
# 281         1.0  //geohack.toolforge.org/geohack.php?pagename=M...
# 282         1.0  //geohack.toolforge.org/geohack.php?pagename=R...
# 283         1.0  //geohack.toolforge.org/geohack.php?pagename=R...
# 284         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
# 285         1.0  //geohack.toolforge.org/geohack.php?pagename=K...
#
#          latitudes     longitudes  latitudes_g  longitudes_g  \
# 0    31°46′17.05″N  35°13′27.65″E    31.771403     35.224347
# 1    31°46′35.93″N  35°13′17.57″E    31.776647     35.221547
# 2       31°46′49″N     35°13′09″E    31.780278     35.219167
# 3              NaN            NaN          NaN           NaN
# 4              NaN            NaN          NaN           NaN
# ..             ...            ...          ...           ...
# 281     31°46′36″N      35°14′3″E    31.776667     35.234167
# 282     31°48′43″N      35°12′0″E    31.811944     35.200000
# 283     31°47′24″N     35°12′14″E    31.790000     35.203889
# 284     31°45′40″N     35°12′25″E    31.761111     35.206944
# 285     31°47′42″N     35°12′16″E    31.795000     35.204444
#
#                          Other_name
# 0                               NaN
# 1                    /Mahane Israel
# 2    /Nahalat Shiva/ Nahalat Shiv’a
# 3                               NaN
# 4                               NaN
# ..                              ...
# 281                             NaN
# 282                             NaN
# 283                             NaN
# 284                             NaN
# 285                             NaN
#
# [286 rows x 17 columns]
